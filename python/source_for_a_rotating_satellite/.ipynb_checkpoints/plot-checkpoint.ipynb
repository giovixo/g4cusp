# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("events.csv")

# %%
df
# Out:
#      event_id       time      angle     pol_x  pol_y     pol_z  energy
# 0           0   0.016646   0.104591  0.994535    0.0  0.104400   100.0
# 1           1   0.020394   0.128142  0.991801    0.0  0.127792   100.0
# 2           2   0.021405   0.134494  0.990969    0.0  0.134089   100.0
# 3           3   0.021984   0.138132  0.990475    0.0  0.137693   100.0
# 4           4   0.022574   0.141834  0.989958    0.0  0.141359   100.0
# ..        ...        ...        ...       ...    ...       ...     ...
# 995       995  10.154000  63.799467  0.567267    0.0  0.823534   100.0
# 996       996  10.180798  63.967841  0.421237    0.0  0.906951   100.0
# 997       997  10.228173  64.265509  0.136711    0.0  0.990611   100.0
# 998       998  10.235954  64.314395  0.088140    0.0  0.996108   100.0
# 999       999  10.242244  64.353917  0.048713    0.0  0.998813   100.0
#
# [1000 rows x 7 columns]

# %%
df['time'].plot()
plt.xlabel('Index')  # X-axis label
plt.ylabel('time (s)')  # Y-axis label
plt.title('rate 10 phs/s, exposure 10 s')  # Title

plt.savefig('time.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
df.plot.scatter(x='pol_x', y='pol_z', color='blue', marker='.')
plt.savefig('polarization_vector.png', dpi=300, bbox_inches='tight')
plt.show()
